# %% [markdown]
# <a href="https://colab.research.google.com/github/pushyag1/BigData_PySpark/blob/main/CCOverride_row_updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
 #loading libraries
import pandas as pd
import os
#import pyspark.sql.functions as func

# %%
#data_input = pd.read_excel('data.xlsx')
df = pd.read_excel('/content/drive/MyDrive/Index/Merged_CCOveride.xlsx')
df
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0_x  ...  HCC59 HCC60  LTIMCAID_O
# 0               0             0             0  ...    NaN   NaN         NaN
# 1               1             1            63  ...    NaN   NaN         NaN
# 2               2             2            64  ...    NaN   NaN         NaN
# 3               3             3           386  ...    NaN   NaN         NaN
# 4               4             4           452  ...    NaN   NaN         NaN
# ...           ...           ...           ...  ...    ...   ...         ...
# 19950       20812          2005          1928  ...    0.0   0.0         1.0
# 19951       20813          2006          1930  ...    0.0   0.0         1.0
# 19952       20814          2007          1982  ...    0.0   0.0         1.0
# 19953       20815          2008          1990  ...    0.0   0.0         1.0
# 19954       20816          2009          2007  ...    1.0   0.0         1.0
#
# [19955 rows x 287 columns]

# %%
df=df.drop(columns=['Unnamed: 0',	'Unnamed: 0.1',	'Unnamed: 0_x'])

# %%
df.head(1)
# Out:
#    PERSON ID  DIAG    HCC  MODEL YEAR  ... HCC56  HCC59  HCC60  LTIMCAID_O
# 0   59011425  N179  135.0        2020  ...   NaN    NaN    NaN         NaN
#
# [1 rows x 284 columns]

# %%
group = df.groupby('PERSON ID')

#df2 = group.apply(lambda x: x[df.iloc[:, 5:]].max())

# %%
df2['PERSON ID']=group.apply(lambda x:x.)

# %%
df1 = df['PERSON ID'].unique()
result = []
for value in df:
  value = result.append(value.unique())

# %%
df.dtypes
# Out:
# PERSON ID       int64
# DIAG           object
# HCC           float64
# MODEL YEAR      int64
# Version        object
#                ...
# NonAged       float64
# HCC56         float64
# HCC59         float64
# HCC60         float64
# LTIMCAID_O    float64
# Length: 284, dtype: object

# %%
df_2021=df[df['MODEL YEAR']== 2021]
df_2021 = df_2021.reset_index(drop=True)
df_2021
# Out:
#       PERSON ID     DIAG    HCC  MODEL YEAR  ... HCC56  HCC59  HCC60  LTIMCAID_O
# 0      71251632     N179  135.0        2021  ...   NaN    NaN    NaN         NaN
# 1      71251632     I509   85.0        2021  ...   NaN    NaN    NaN         NaN
# 2      71251632     I482   96.0        2021  ...   NaN    NaN    NaN         NaN
# 3      71251632  T83410A  176.0        2021  ...   NaN    NaN    NaN         NaN
# 4      71251632     D696   48.0        2021  ...   NaN    NaN    NaN         NaN
# ...         ...      ...    ...         ...  ...   ...    ...    ...         ...
# 9920  128707425     I739  108.0        2021  ...   0.0    0.0    0.0         1.0
# 9921   19804968     I739  108.0        2021  ...   0.0    0.0    0.0         1.0
# 9922  132178472    E6601   22.0        2021  ...   0.0    0.0    0.0         1.0
# 9923  152542839    E6601   22.0        2021  ...   0.0    0.0    0.0         1.0
# 9924   92941551     F325   59.0        2021  ...   0.0    1.0    0.0         1.0
#
# ...

# %%
df_2020=df[df['MODEL YEAR']!= 2021]
df_2020 = df_2020.reset_index(drop=True)
df_2020
# Out:
#        PERSON ID    DIAG    HCC  MODEL YEAR  ... HCC56  HCC59  HCC60  LTIMCAID_O
# 0       59011425    N179  135.0        2020  ...   NaN    NaN    NaN         NaN
# 1       59011425   E1142   18.0        2020  ...   NaN    NaN    NaN         NaN
# 2       59011425   E1142   75.0        2020  ...   NaN    NaN    NaN         NaN
# 3       59011425  E11610   18.0        2020  ...   NaN    NaN    NaN         NaN
# 4       59011425    E118   18.0        2020  ...   NaN    NaN    NaN         NaN
# ...          ...     ...    ...         ...  ...   ...    ...    ...         ...
# 10025  128707425    I739  108.0        2020  ...   0.0    0.0    0.0         1.0
# 10026   19804968    I739  108.0        2020  ...   0.0    0.0    0.0         1.0
# 10027  132178472   E6601   22.0        2020  ...   0.0    0.0    0.0         1.0
# 10028  152542839   E6601   22.0        2020  ...   0.0    0.0    0.0         1.0
# 10029   92941551    F325   59.0        2020  ...   0.0    1.0    0.0         1.0
#
# ...

# %%
dfList=[df_2020,df_2021]

# %%
result = []
for dat in dfList:
  dat = result.append(dat.groupby(['PERSON ID','AGEF','SEX','MODEL YEAR'] ).max().reset_index())

# %%
[df_2020,df_2021]=result

# %%
df_2020
# Out:
#      PERSON ID  AGEF  SEX  MODEL YEAR  ... HCC56  HCC59 HCC60  LTIMCAID_O
# 0      1049180    82    1        2020  ...   0.0    0.0   0.0         1.0
# 1      1393478    81    2        2020  ...   0.0    0.0   0.0         1.0
# 2      2660169    76    1        2020  ...   0.0    0.0   0.0         1.0
# 3      2693705    42    2        2020  ...   0.0    1.0   0.0         1.0
# 4      2794680    74    1        2020  ...   0.0    0.0   0.0         1.0
# ..         ...   ...  ...         ...  ...   ...    ...   ...         ...
# 367  157935578    69    2        2020  ...   0.0    0.0   0.0         1.0
# 368  158141657    68    2        2020  ...   0.0    0.0   0.0         1.0
# 369  158547028    67    1        2020  ...   0.0    1.0   0.0         1.0
# 370  159127629    76    2        2020  ...   0.0    0.0   0.0         1.0
# 371  159798717    66    2        2020  ...   0.0    0.0   0.0         1.0
#
# [372 rows x 284 columns]

# %%
df_2020.to_excel("data_2020.xlsx")
df_2021.to_excel("data_2021.xlsx")
