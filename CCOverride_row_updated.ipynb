# %% [markdown]
# <a href="https://colab.research.google.com/github/pushyag1/BigData_PySpark/blob/main/CCOverride_row_updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 #loading libraries
import pandas as pd
import os
#import pyspark.sql.functions as func

# %%
#data_input = pd.read_excel('data.xlsx')
df = pd.read_excel('/content/drive/MyDrive/Index/Merged_CCOveride.xlsx')
df
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0_x  ...  HCC59 HCC60  LTIMCAID_O
# 0               0             0             0  ...    NaN   NaN         NaN
# 1               1             1            63  ...    NaN   NaN         NaN
# 2               2             2            64  ...    NaN   NaN         NaN
# 3               3             3           386  ...    NaN   NaN         NaN
# 4               4             4           452  ...    NaN   NaN         NaN
# ...           ...           ...           ...  ...    ...   ...         ...
# 19950       20812          2005          1928  ...    0.0   0.0         1.0
# 19951       20813          2006          1930  ...    0.0   0.0         1.0
# 19952       20814          2007          1982  ...    0.0   0.0         1.0
# 19953       20815          2008          1990  ...    0.0   0.0         1.0
# 19954       20816          2009          2007  ...    1.0   0.0         1.0
#
# [19955 rows x 287 columns]

# %%
df=df.drop(columns=['Unnamed: 0',	'Unnamed: 0.1',	'Unnamed: 0_x','Unnamed: 0_y','Model Year','Model Version'])

# %%
df.head(1)
# Out:
#    PERSON ID  DIAG    HCC  MODEL YEAR  ... HCC56  HCC59  HCC60  LTIMCAID_O
# 0   59011425  N179  135.0        2020  ...   NaN    NaN    NaN         NaN
#
# [1 rows x 281 columns]

# %%
Versions=df['Version'].unique()
Versions
# Out:
# array(['ESRD-P1', 'ESRD-P2', 'RX', 'V22', 'V24'], dtype=object)

# %%
years=df['MODEL YEAR'].unique()

# %%
# group = df["Company"]
# # group by that period
# agg = df.groupby([group])
# for year, group in agg:
#     print(group)

# %%
dfList1=[df]

# %%
result1=[]
for version, df_version in df.groupby('Version'):
  for year, df_year in df_version.groupby('MODEL YEAR'):
    result1.append(df_year)

result = []
for dat in result1:
  dat = result.append(dat.groupby(['PERSON ID',] ).max().reset_index())

# %%
[d1,d2,d3,d4,d5,d6,d7,d8,d9,d10]=result

# %%
d1.head(1)
# Out:
#    PERSON ID  DIAG    HCC  MODEL YEAR  ... HCC56  HCC59  HCC60  LTIMCAID_O
# 0    1049180  Z794  139.0        2020  ...   NaN    NaN    NaN         NaN
#
# [1 rows x 281 columns]

# %%
d1.to_excel('ESRD-P1-2020.xlsx')
d2.to_excel('ESRD-P1-2021.xlsx')
d3.to_excel('ESRD-P2-2020.xlsx')
d4.to_excel('ESRD-P2-2021.xlsx')
d5.to_excel('RX-2020.xlsx')
d6.to_excel('RX-2021.xlsx')
d7.to_excel('V22-2020.xlsx')
d8.to_excel('V22-2021.xlsx')
d9.to_excel('V24-2020.xlsx')
d10.to_excel('V24-2021.xlsx')
