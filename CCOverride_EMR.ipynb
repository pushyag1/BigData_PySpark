# %% [markdown]
# <a href="https://colab.research.google.com/github/pushyag1/BigData_PySpark/blob/main/CCOverride_EMR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Use colab for faster processing time. Before you initialize your runtime, please remember to upload these excel sheets to the local files.
#
# * CC Mapping.xlsx
# *Diagnosis Input File.xlsx
# * Sample Input Person File.xlsx

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/gdrive/My Drive/Index/')

# %%
# !pip install xlrd

# %%
sample_input = '/content/drive/MyDrive/Index/Sample Input Person File.xlsx'
df_sample_input = pd.read_excel(sample_input)
df_sample_input
# Out:
#      Person ID        DOB  Gender  OREC  Unnamed: 4  Unnamed: 5    1    Male
# 0     95307787 1944-03-23       1     0         NaN         NaN  2.0  Female
# 1     67928991 1930-05-29       2     0         NaN         NaN  NaN     NaN
# 2    124623786 1948-07-30       1     0         NaN         NaN  NaN     NaN
# 3     73717666 1935-06-12       2     0         NaN         NaN  NaN     NaN
# 4    111693065 1927-05-03       2     0         NaN         NaN  NaN     NaN
# ..         ...        ...     ...   ...         ...         ...  ...     ...
# 495   40752647 1953-10-14       2     0         NaN         NaN  NaN     NaN
# 496  150788750 1953-10-15       1     0         NaN         NaN  NaN     NaN
# 497   87823398 1966-09-24       2     1         NaN         NaN  NaN     NaN
# 498   77246378 1953-09-26       2     0         NaN         NaN  NaN     NaN
# 499   20266147 1966-10-07       2     1         NaN         NaN  NaN     NaN
#
# [500 rows x 8 columns]

# %%
df_sample_input.columns
# Out:
# Index(['Person ID', 'DOB', 'Gender', 'OREC', 'Unnamed: 4', 'Unnamed: 5', 1,
#        'Male'],
#       dtype='object')

# %%
df_sample_input= df_sample_input.drop(columns=['Unnamed: 4','Unnamed: 5',1,'Male'])

# %%
df_sample_input
# Out:
#      Person ID        DOB  Gender  OREC
# 0     95307787 1944-03-23       1     0
# 1     67928991 1930-05-29       2     0
# 2    124623786 1948-07-30       1     0
# 3     73717666 1935-06-12       2     0
# 4    111693065 1927-05-03       2     0
# ..         ...        ...     ...   ...
# 495   40752647 1953-10-14       2     0
# 496  150788750 1953-10-15       1     0
# 497   87823398 1966-09-24       2     1
# 498   77246378 1953-09-26       2     0
# 499   20266147 1966-10-07       2     1
#
# [500 rows x 4 columns]

# %%
Diagnosis_file = '/content/drive/MyDrive/Index/Diagnosis Input File.xlsx'
df_diagnosis = pd.read_excel(Diagnosis_file)
df_diagnosis
# Out:
#       PERSON ID DIAGNOSIS CODE
# 0      95307787        E1165
# 1      95307787        E1122
# 2      95307787        E230
# 3      95307787        E119
# 4      95307787        E1151
# ...         ...            ...
# 1987  106185394        E6601
# 1988   31405988        M069
# 1989   40752647        Z6841
# 1990  150788750        F10929
# 1991   87823398        F3110
#
# [1992 rows x 2 columns]

# %% [markdown]
# Removing whitespaces from string objects

# %%
l= df_diagnosis['DIAGNOSIS CODE'].tolist()
m = [x.strip(' ') for x in l]
df_diagnosis['DIAGNOSIS CODE']=m

# %%
# df_diagnosis.loc[df_diagnosis['DIAGNOSIS CODE']=='K7201']

# %%
CC_mapping_file = '/content/drive/MyDrive/Index/CC Mapping.xlsx'
df_CC_mapping = pd.read_excel(CC_mapping_file)
df_CC_mapping
# Out:
#        MODEL YEAR  VERSION DIAGNOSIS CODE   CC
# 0            2020       RX           A072    5
# 1            2020       RX           A310    5
# 2            2020       RX           A312    5
# 3            2020       RX          A3681  186
# 4            2020       RX           A391   41
# ...           ...      ...            ...  ...
# 87817        2021  ESRD-P2         Z95811  186
# 87818        2021  ESRD-P2         Z95812  186
# 87819        2021  ESRD-P2          Z9911   82
# 87820        2021  ESRD-P2          Z9912   82
# 87821        2021  ESRD-P2           Z992  134
#
# [87822 rows x 4 columns]

# %%
p= df_CC_mapping['DIAGNOSIS CODE'].tolist()
q = [x.strip(' ') for x in p]
df_CC_mapping['DIAGNOSIS CODE']=q

df_CC_mapping
# Out:
#        MODEL YEAR  VERSION DIAGNOSIS CODE   CC
# 0            2020       RX           A072    5
# 1            2020       RX           A310    5
# 2            2020       RX           A312    5
# 3            2020       RX          A3681  186
# 4            2020       RX           A391   41
# ...           ...      ...            ...  ...
# 87817        2021  ESRD-P2         Z95811  186
# 87818        2021  ESRD-P2         Z95812  186
# 87819        2021  ESRD-P2          Z9911   82
# 87820        2021  ESRD-P2          Z9912   82
# 87821        2021  ESRD-P2           Z992  134
#
# [87822 rows x 4 columns]

# %%
# h= df_CC_mapping.loc[(df_CC_mapping['VERSION']=='V24') & (df_CC_mapping['MODEL YEAR']==2021)]['CC'].unique().tolist()
# sorted(h)

# %%
# df_diagnosis.loc[df_diagnosis['DIAGNOSIS CODE']=='F0151']

# %%
type(df_CC_mapping['MODEL YEAR'][0])
# Out:
# numpy.int64

# %%
versions = df_CC_mapping['VERSION'].unique().tolist()

# %%
model_years= df_CC_mapping['MODEL YEAR'].unique().tolist()

# %% [markdown]
# Creating a list of all diagnosis codes from diagnosis input file and removing whitespaces.

# %%
diag_list=[]
for element in df_diagnosis['DIAGNOSIS CODE']:
  diag_list.append(element)
diag_list = [x.strip(' ') for x in diag_list]

# %%
'E1165' in diag_list
# Out:
# True

# %%
len(diag_list)
# Out:
# 1992

# %%
versions
# Out:
# ['RX', 'V24', 'V22', 'ESRD-P1', 'ESRD-P2']

# %%
df_diagnosis
# Out:
#       PERSON ID DIAGNOSIS CODE
# 0      95307787          E1165
# 1      95307787          E1122
# 2      95307787           E230
# 3      95307787           E119
# 4      95307787          E1151
# ...         ...            ...
# 1987  106185394          E6601
# 1988   31405988           M069
# 1989   40752647          Z6841
# 1990  150788750         F10929
# 1991   87823398          F3110
#
# [1992 rows x 2 columns]

# %%
# df_diagnosis.loc[(df_diagnosis['DIAGNOSIS CODE']=='F0151')]

# %% [markdown]
# **Example**: Locating particular version and model year in a dataframe

# %%
df_v24_21= df_CC_mapping.loc[(df_CC_mapping['VERSION']==str('V24')) & (df_CC_mapping['MODEL YEAR']== 2021)]

df_v24_21
# Out:
#        MODEL YEAR VERSION DIAGNOSIS CODE   CC
# 48292        2021     V24          A0103  115
# 48293        2021     V24          A0104   39
# 48294        2021     V24          A0105   39
# 48295        2021     V24           A021    2
# 48296        2021     V24          A0222  115
# ...           ...     ...            ...  ...
# 58044        2021     V24         Z95811  186
# 58045        2021     V24         Z95812  186
# 58046        2021     V24          Z9911   82
# 58047        2021     V24          Z9912   82
# 58048        2021     V24           Z992  134
#
# [9757 rows x 4 columns]

# %%
df_v24_21.loc[df_v24_21['CC']==51]
# Out:
#        MODEL YEAR VERSION DIAGNOSIS CODE  CC
# 50538        2021     V24          F0151  51
# 50540        2021     V24          F0281  51
# 50542        2021     V24          F0391  51
# 51234        2021     V24           G910  51
# 51235        2021     V24           G911  51
# 51236        2021     V24           G912  51
# 51237        2021     V24           G913  51
# 51238        2021     V24           G914  51
# 51239        2021     V24           G918  51
# 51240        2021     V24           G919  51

# %%
import numpy as np

# %% [markdown]
# # Automating for each model year and version

# %%
for version in versions:
  for year in model_years:
    
    #Part 1: Creating custom dataframe
    df_temp= df_CC_mapping.loc[(df_CC_mapping['VERSION']==str(version)) & (df_CC_mapping['MODEL YEAR']== year)]  #creating custom dataframe based on given version and model year from CC_Mapping dataframe
    

    #Part 2: Mapping Diag codes from Diagnosis input file(diag_list) with diag codes from CC Mapping file
    CC_list=[]
    for i in (diag_list):
      x= df_temp.loc[i==df_temp['DIAGNOSIS CODE']]['CC'].tolist() # Searching where value from list equals row value in dataframe and copying corresponding CC value to list
      CC_list.append(x)
    # print(CC_list)


    #Part 3: Creating new dataframe for each instance 
    df_main= pd.DataFrame()
    df_main['PERSON ID']= list(df_diagnosis['PERSON ID'])
    df_main['DIAGNOSIS CODE']= list(df_diagnosis['DIAGNOSIS CODE']) 
    df_main['HCC']= CC_list  # CC values obtained after mapping from Part 2.
    df_main['MODEL YEAR']= str(year)
    df_main['Version']= str(version)

    #Part 4: Finding all possible HCC values from CC Mapping file
    h= df_temp['CC'].unique().tolist()
    unique_HCC= sorted(h)
    # print(unique_HCC)

    # Part 5: Creating new columns with column names as HCC values obtained from Part 4
    columns_df=[]
    for value in (unique_HCC):
      columns_df.append('HCC'+str(value)) # Example: HCC1,HCC2,HCC3 etc
    #print(columns_df)
    for col in range(len(columns_df)):
      df_main[columns_df[col]]=0  #adding zero's to every column 

    #Part 6: Turning 0's to 1's at corresponding HCC columns

    for v in range(len(df_main)):                          # here v is used as index value
      for v2 in range(len(df_main.iloc[v][2])):            # Indicating each row value in HCC column. Each cell in the HCC column contains a list element. Ex: [18],[18,108],[18,106,108].
        df_main.at[v,'HCC'+ str(df_main.iloc[v][2][v2])]=1  # the str part outputs the value of HCC present in each list. v2 is basically iterating through the lenght of list in each row.


    #Part 5: Turning list objects in the HCC column to string objects
    df_main['HCC'] = [','.join(map(str, l)) for l in df_main['HCC']]    # Ex: turning [18,108] to 18,108

    #Part 6: Generating individual excel sheets for each model year and version
    df_main.to_excel(str(version)+'_'+str(year)+'.xlsx') #Outputting excel files for each scenario

# %%
# Demographic_input = '/content/Demography_Variable_Calculated.xlsx'
# df_Demographic_input = pd.read_excel(Demographic_input)
# df_Demographic_input

# %%
d1 = '/content/ESRD-P1_2020.xlsx'
df_d1 = pd.read_excel(d1)
d2 = '/content/ESRD-P1_2021.xlsx'
df_d2 = pd.read_excel(d2)
d3 = '/content/ESRD-P2_2020.xlsx'
df_d3 = pd.read_excel(d3)
d4 = '/content/ESRD-P2_2021.xlsx'
df_d4 = pd.read_excel(d4)
d5 = '/content/RX_2020.xlsx'
df_d5 = pd.read_excel(d5)
d6 = '/content/RX_2021.xlsx'
df_d6 = pd.read_excel(d6)
d7 = '/content/V22_2020.xlsx'
df_d7 = pd.read_excel(d7)
d8 = '/content/V22_2021.xlsx'
df_d8 = pd.read_excel(d8)
d9 = '/content/V24_2020.xlsx'
df_d9 = pd.read_excel(d9)
d10 = '/content/V24_2021.xlsx'
df_d10 = pd.read_excel(d10)

# %%
demo_rules = '/content/drive/MyDrive/Index/Demography Variable Calculations.xlsx'
df_DV = pd.read_excel(demo_rules)
df_DV
# Out:
#      Model Year  ...                                              Logic
# 0          2020  ...  CASE WHEN (AGEF < 65 AND OREC <>'0') THEN 1 EL...
# 1          2020  ...  CASE WHEN (AGEF < 65 AND OREC <>'0') THEN 1 EL...
# 2          2021  ...  CASE WHEN (AGEF < 65 AND OREC <>'0') THEN 1 EL...
# 3          2021  ...  CASE WHEN (AGEF < 65 AND OREC <>'0') THEN 1 EL...
# 4          2020  ...  CASE WHEN ((SEX = '2') AND (AGEF BETWEEN 0 AND...
# ..          ...  ...                                                ...
# 737        2021  ...  CASE WHEN (SEX = '1' AND (AGEF BETWEEN 90 AND ...
# 738        2021  ...  CASE WHEN (SEX = '1' AND (AGEF > 94)) THEN 1 E...
# 739        2021  ...  CASE WHEN ((NEMCAID <=0) and ((CASE WHEN ((AGE...
# 740        2021  ...  CASE WHEN ( (NEMCAID <=0) and ((CASE WHEN ((AG...
# 741        2021  ...  CASE WHEN ((OREC='1') AND ((CASE WHEN (AGEF < ...
#
# [742 rows x 4 columns]

# %%
demo_file = '/content/drive/MyDrive/Index/Demography_File_updated.xlsx'
df = pd.read_excel(demo_file)
df
# Out:
#      Person ID        DOB  Gender  OREC  ...  ESRD  MCAID  Age  Model Year
# 0     95307787 1944-03-23       1     0  ...     1      1   75        2020
# 1     95307787 1944-03-23       1     0  ...     1      1   76        2021
# 2     67928991 1930-05-29       2     0  ...     0      1   89        2020
# 3     67928991 1930-05-29       2     0  ...     0      1   90        2021
# 4    124623786 1948-07-30       1     0  ...     0      0   71        2020
# ..         ...        ...     ...   ...  ...   ...    ...  ...         ...
# 995   40752647 1953-10-14       2     0  ...     1      1   67        2021
# 996  150788750 1953-10-15       1     0  ...     1      1   67        2021
# 997   87823398 1966-09-24       2     1  ...     0      1   54        2021
# 998   77246378 1953-09-26       2     0  ...     0      0   67        2021
# 999   20266147 1966-10-07       2     1  ...     0      1   54        2021
#
# [1000 rows x 10 columns]

# %%
versions = df_DV['Model Version'].unique().tolist()
versions
# Out:
# ['ESRD-P1', 'ESRD-P2', 'RX', 'V22', 'V24']

# %%
model_years= df_DV['Model Year'].unique().tolist()
model_years
# Out:
# [2020, 2021]

# %%
for version in versions:
  for model_year in model_years:
    
    df1 = {}
    
    df1 = df.copy()
    #df1 = df.iloc[:,0:9].copy()

  
    df1 = df.loc[df['Model Year'] == model_year]
    

    #df2 = df[]
    #print(df1)

    

    #df1['Model Year_new'] = str(model_year)
    df1['Model Version'] = str(version)

    
    #df.loc[df['Model Year'] == 2021]

    if (version == 'ESRD-P1') or (version == 'ESRD-P2'):
      df1.loc[(df1['Age'] >= 65), ['GE65_DUR10PL', 'GE65_DUR4_9']] = 1
      df1.loc[(df1['Age'] < 65), ['LT65_DUR10PL','LT65_DUR4_9']] = 1
      df1.loc[(df1['Gender'] == 2) & (df1['Age'] > 84), 'NEF85_GT'] = 1
      df1.loc[(df1['Gender'] == 1) & (df1['Age'] > 84), 'NEM85_GT'] = 1
      df1.loc[(df1['OREC'] == 1) & (((df1['Age'] < 65) & (df1['OREC'] != 0)) == 0), 'ORIGDS'] = 1
      df1.loc[(df1['NEMCAID'] <= 0) & ((df1['OREC'] == 1) <= 0), 'NMCAID_NORIGDIS'] = 1
      df1.loc[(df1['NEMCAID'] <= 0) & (((df1['Age'] >= 65) & (df1['OREC'] == 1)) <= 0), 'NMCAID_NORIGDIS_G'] = 1
      df1.loc[(df1['NEMCAID'] <= 0) & ((df1['OREC'] == 1) > 0), 'NMCAID_ORIGDIS'] = 1
      df1.loc[(df1['NEMCAID'] <= 0) & (((df1['Age'] >= 65) & (df1['OREC'] == 1)) > 0), 'NMCAID_ORIGDIS_G'] = 1
      df1.loc[(df1['Gender'] == 2) & (df1['OREC'].isin([2,3])) & (df1['Age'] >= 65), 'Originally_ESRD_Female'] = 1
      df1.loc[(df1['Gender'] == 1) & (df1['OREC'].isin([2,3])) & (df1['Age'] >= 65), 'Originally_ESRD_Male'] = 1
      df1.loc[(((df1['OREC'] == 1) & (((df1['Age'] < 65) & (df1['OREC'] != 0)) == 0)) == 1) & (df1['Gender'] == 2), 'OriginallyDisabled_Female'] = 1
      df1.loc[(((df1['OREC'] == 1) & (((df1['Age'] < 65) & (df1['OREC'] != 0)) == 0)) == 1) & (df1['Gender'] == 1), 'OriginallyDisabled_Male'] = 1
      df1.loc[(df1['Gender'] == 2) & (df1['MCAID'] == 1) & ((1 - ((df1['Age'] < 65) & (df1['OREC'] != 0))) == 1), ['MCAID_Female_Aged']] = 1
      df1.loc[(df1['Gender'] == 1) & (df1['MCAID'] == 1) & ((1 - ((df1['Age'] < 65) & (df1['OREC'] != 0))) == 1), ['MCAID_Male_Aged']] = 1
      df1.loc[(df1['Gender'] == 2) & (df1['MCAID'] == 1) & (((df1['Age'] < 65) & (df1['OREC'] != 0)) == 1), ['MCAID_Female_NonAged']] = 1
      df1.loc[(df1['Gender'] == 2) & (df1['MCAID'] == 1) & (((df1['Age'] < 65) & (df1['OREC'] != 0)) == 1), ['MCAID_Male_NonAged']] = 1
      df1.loc[(df1['NEMCAID'] > 0) & ((df1['OREC'] == 1) <= 0), 'MCAID_NORIGDIS'] = 1
      df1.loc[(df1['NEMCAID'] > 0) & (((df1['Age'] >= 65) & (df1['OREC'] == 1)) <= 0), 'MCAID_NORIGDIS_G'] = 1
      df1.loc[(df1['MCAID'] == 1), 'MCAID_O'] = 1
      df1.loc[(df1['NEMCAID'] > 0) & ((df1['OREC'] == 1) > 0), 'MCAID_ORIGDIS'] = 1
      df1.loc[(df1['NEMCAID'] > 0) & (((df1['Age'] >= 65) & (df1['OREC'] == 1)) > 0), 'MCAID_ORIGDIS_G'] = 1
      df1.loc[(df1['OREC'] == 1) , 'NE_ORIGDS'] = 1
      df1.loc[(df1['OREC'] == 1) & (df1['Age'] >= 65), 'NE_ORIGDS_G'] = 1
      df1['KIDNEY_ONLY_1M'] = 1
      df1['KIDNEY_ONLY_2M'] = 1
      df1['KIDNEY_ONLY_3M'] = 1



    if version == 'ESRD-P2' or version == 'ESRD-P1'or version == 'V22' or version == 'V24':
      df1.loc[(df1['Age'] < 65) & (df1['OREC'] != 0), 'DISABL'] = 1

    if (version == 'ESRD-P2'):
      if (model_year == 2020) or (model_year == 2021):
        df1.loc[(df1['Age'] >= 65), ['GE65_DUR10PL_LTI', 'GE65_DUR10PL_NE', 'GE65_DUR4_9_LTI', 'GE65_DUR4_9_NE']] = 1
        df1.loc[(df1['Age'] < 65), ['LT65_DUR10PL_LTI','LT65_DUR10PL_NE','LT65_DUR4_9_LTI','LT65_DUR4_9_NE']] = 1

    if version == 'RX':
      df1.loc[(df1['ESRD'] == 1) & ((df1['OREC'] == 1 & ~((df1['Age'] < 65) & (df1['OREC'] != 0))) == 0), 'ESRD_NORIGDIS'] = 1
      df1.loc[(df1['ESRD'] == 1) & ((df1['OREC'] == 1 & ~((df1['Age'] < 65) & (df1['OREC'] != 0))) == 1), 'ESRD_ORIGDIS'] = 1
      df1.loc[(((df1['OREC'] == 1) & ~((df1['Age'] < 65) & (df1['OREC'] != 0))) == 1) & (df1['Gender'] == 2), 'F65OD'] = 1
      df1.loc[(((df1['OREC'] == 1) & ~((df1['Age'] < 65) & (df1['OREC'] != 0))) == 1) & (df1['Gender'] == 1), 'M65OD'] = 1
      df1.loc[(df1['ESRD'] == 0) & ((df1['OREC'] == 1 & ~((df1['Age'] < 65) & (df1['OREC'] != 0))) == 0), 'NESRD_NORIGDIS'] = 1
      df1.loc[(df1['ESRD'] == 0) & ((df1['OREC'] == 1 & ~((df1['Age'] < 65) & (df1['OREC'] != 0))) == 1), 'NESRD_ORIGDIS'] = 1
      df1.loc[(df1['OREC'] == 1) & ~((df1['Age'] < 65) & (df1['OREC'] != 0)) , 'ORIGDS'] = 1
      df1.loc[((((df1['Gender'] == 2) & ((df1['Age'] >= 0) & (df1['Age'] <= 34))) == 1) | 
              (((df1['Gender'] == 2) & ((df1['Age'] >= 35) & (df1['Age'] <= 44))) == 1) |
              (((df1['Gender'] == 2) & ((df1['Age'] >= 45) & (df1['Age'] <= 54))) == 1) |
              (((df1['Gender'] == 2) & ((df1['Age'] >= 55) & (df1['Age'] <= 59))) == 1) |
              (((df1['Gender'] == 2) & ((df1['Age'] >= 60) & (df1['Age'] <= 64))) == 1) |
              (((df1['Gender'] == 1) & ((df1['Age'] >= 0) & (df1['Age'] <= 34))) == 1) | 
              (((df1['Gender'] == 1) & ((df1['Age'] >= 35) & (df1['Age'] <= 44))) == 1) |
              (((df1['Gender'] == 1) & ((df1['Age'] >= 45) & (df1['Age'] <= 54))) == 1) |
              (((df1['Gender'] == 1) & ((df1['Age'] >= 55) & (df1['Age'] <= 59))) == 1) |
              (((df1['Gender'] == 1) & ((df1['Age'] >= 60) & (df1['Age'] <= 64))) == 1)), 'NonAged'] = 1
          
    if version == 'V22' or version == 'V24':
      df1.loc[(df1['NEMCAID'] > 0) & (((df1['OREC'] == 1) & (df1['Age'] >= 65)) <= 0), 'MCAID_NORIGDIS'] = 1
      df1.loc[(df1['NEMCAID'] > 0) & (((df1['OREC'] == 1) & (df1['Age'] >= 65)) > 0), 'MCAID_ORIGDIS'] = 1
      df1.loc[(df1['Age'] >= 65) & (df1['OREC'] == 1) , 'NE_ORIGDS'] = 1
      df1.loc[(df1['NEMCAID'] <= 0) & (((df1['OREC'] == 1) & (df1['Age'] >= 65)) <= 0), 'NMCAID_NORIGDIS'] = 1
      df1.loc[(df1['NEMCAID'] <= 0) & (((df1['OREC'] == 1) & (df1['Age'] >= 65)) > 0), 'NMCAID_ORIGDIS'] = 1
      df1.loc[(df1['OREC'] == 1) & (((df1['Age'] < 65) & (df1['OREC'] != 0)) == 0), 'ORIGDS'] = 1

    if version == 'V24':
      df1.loc[df1['LTIMCAID'] == 1, 'LTIMCAID_O'] = 1


    df1.loc[(df1['Gender'] == 2) & (df1['Age'] >= 0) & (df1['Age'] <= 34), ['F0_34','NEF0_34']] = 1
    df1.loc[(df1['Gender'] == 2) & (df1['Age'] >= 35) & (df1['Age'] <= 44), ['F35_44','NEF35_44']] = 1
    df1.loc[(df1['Gender'] == 2) & (df1['Age'] >= 45) & (df1['Age'] <= 54), ['F45_54','NEF45_54']] = 1
    df1.loc[(df1['Gender'] == 2) & (df1['Age'] >= 55) & (df1['Age'] <= 59), ['F55_59','NEF55_59']] = 1
    df1.loc[(df1['Gender'] == 2) & (df1['Age'] >= 60) & (df1['Age'] <= 64), 'F60_64'] = 1
    df1.loc[(df1['Gender'] == 2) & (df1['Age'] >= 65) & (df1['Age'] <= 69), 'F65_69'] = 1
    df1.loc[(df1['Gender'] == 2) & (df1['Age'] >= 70) & (df1['Age'] <= 74), ['F70_74','NEF70_74']] = 1
    df1.loc[(df1['Gender'] == 2) & (df1['Age'] >= 75) & (df1['Age'] <= 79), ['F75_79','NEF75_79']] = 1
    df1.loc[(df1['Gender'] == 2) & (df1['Age'] >= 80) & (df1['Age'] <= 84), ['F80_84','NEF80_84']] = 1
    df1.loc[(df1['Gender'] == 2) & (df1['Age'] >= 85) & (df1['Age'] <= 89), ['F85_89','NEF85_89']] = 1
    df1.loc[(df1['Gender'] == 2) & (df1['Age'] >= 90) & (df1['Age'] <= 94), ['F90_94','NEF90_94']] = 1
    df1.loc[(df1['Gender'] == 2) & (df1['Age'] > 94), ['F95_GT','NEF95_GT']] = 1  

    df1.loc[(df1['Gender'] == 1) & (df1['Age'] >= 0) & (df1['Age'] <= 34), ['M0_34','NEM0_34']] = 1
    df1.loc[(df1['Gender'] == 1) & (df1['Age'] >= 35) & (df1['Age'] <= 44), ['M35_44','NEM35_44']]= 1
    df1.loc[(df1['Gender'] == 1) & (df1['Age'] >= 45) & (df1['Age'] <= 54), ['M45_54','NEM45_54']] = 1
    df1.loc[(df1['Gender'] == 1) & (df1['Age'] >= 55) & (df1['Age'] <= 59), ['M55_59','NEM55_59']] = 1
    df1.loc[(df1['Gender'] == 1) & (df1['Age'] >= 60) & (df1['Age'] <= 64), 'M60_64'] = 1
    df1.loc[(df1['Gender'] == 1) & (df1['Age'] >= 65) & (df1['Age'] <= 69), 'M65_69'] = 1
    df1.loc[(df1['Gender'] == 1) & (df1['Age'] >= 70) & (df1['Age'] <= 74), ['M70_74','NEM70_74']] = 1
    df1.loc[(df1['Gender'] == 1) & (df1['Age'] >= 75) & (df1['Age'] <= 79), ['M75_79','NEM75_79']] = 1
    df1.loc[(df1['Gender'] == 1) & (df1['Age'] >= 80) & (df1['Age'] <= 84), ['M80_84','NEM80_84']] = 1
    df1.loc[(df1['Gender'] == 1) & (df1['Age'] >= 85) & (df1['Age'] <= 89), ['M85_89','NEM85_89']] = 1
    df1.loc[(df1['Gender'] == 1) & (df1['Age'] >= 90) & (df1['Age'] <= 94), ['M90_94','NEM90_94']] = 1
    df1.loc[(df1['Gender'] == 1) & (df1['Age'] > 94), ['M95_GT','NEM95_GT']] = 1

    
    df1.loc[(df1['Gender'] == 2) & (((df1['Age'] >= 60) & (df1['Age'] <= 63)) | ((df1['Age'] == 64) & (df1['OREC'] != 0))), 'NEF60_64'] = 1
    df1.loc[(df1['Gender'] == 2) & ((df1['Age'] == 65) | ((df1['Age'] == 64) & (df1['OREC'] == 0))), 'NEF65'] = 1

    df1.loc[(df1['Gender'] == 2) & (df1['Age'] == 66), 'NEF66'] = 1
    df1.loc[(df1['Gender'] == 2) & (df1['Age'] == 67), 'NEF67'] = 1
    df1.loc[(df1['Gender'] == 2) & (df1['Age'] == 68), 'NEF68'] = 1
    df1.loc[(df1['Gender'] == 2) & (df1['Age'] == 69), 'NEF69'] = 1

    df1.loc[(df1['Gender'] == 1) & (((df1['Age'] >= 60) & (df1['Age'] <= 63)) | ((df1['Age'] == 64) & (df1['OREC'] != 0))), 'NEM60_64'] = 1
    df1.loc[(df1['Gender'] == 1) & ((df1['Age'] == 65) | ((df1['Age'] == 64) & (df1['OREC'] == 0))), 'NEM65'] = 1

    df1.loc[(df1['Gender'] == 1) & (df1['Age'] == 66), 'NEM66'] = 1
    df1.loc[(df1['Gender'] == 1) & (df1['Age'] == 67), 'NEM67'] = 1
    df1.loc[(df1['Gender'] == 1) & (df1['Age'] == 68), 'NEM68'] = 1
    df1.loc[(df1['Gender'] == 1) & (df1['Age'] == 69), 'NEM69'] = 1    
    
    df1 = df1.fillna(0)

    df1.to_excel(str(version)+'_'+ str(model_year)+ str('DV')+ '.xlsx')

# %%
dv1 = '/content/ESRD-P1_2020DV.xlsx'
df_dv1 = pd.read_excel(dv1)
dv2 = '/content/ESRD-P1_2021DV.xlsx'
df_dv2 = pd.read_excel(dv2)
dv3 = '/content/ESRD-P2_2020DV.xlsx'
df_dv3 = pd.read_excel(dv3)
dv4 = '/content/ESRD-P2_2021DV.xlsx'
df_dv4 = pd.read_excel(dv4)
dv5 = "/content/RX_2020DV.xlsx"
df_dv5 = pd.read_excel(dv5)
dv6 = '/content/RX_2021DV.xlsx'
df_dv6 = pd.read_excel(dv6)
dv7 = '/content/V22_2020DV.xlsx'
df_dv7 = pd.read_excel(dv7)
dv8 = '/content/V22_2021DV.xlsx'
df_dv8 = pd.read_excel(dv8)
dv9 = '/content/V24_2020DV.xlsx'
df_dv9 = pd.read_excel(dv9)
dv10 = '/content/V24_2021DV.xlsx'
df_dv10 = pd.read_excel(dv10)

# %%
df_dv1
# Out:
#      Unnamed: 0  Person ID        DOB  Gender  ...  NEM66  NEM67  NEM68  NEM69
# 0             0   95307787 1944-03-23       1  ...      0      0      0      0
# 1             2   67928991 1930-05-29       2  ...      0      0      0      0
# 2             4  124623786 1948-07-30       1  ...      0      0      0      0
# 3             6   73717666 1935-06-12       2  ...      0      0      0      0
# 4             8  111693065 1927-05-03       2  ...      0      0      0      0
# ..          ...        ...        ...     ...  ...    ...    ...    ...    ...
# 495         504   40752647 1953-10-14       2  ...      0      0      0      0
# 496         505  150788750 1953-10-15       1  ...      1      0      0      0
# 497         506   87823398 1966-09-24       2  ...      0      0      0      0
# 498         507   77246378 1953-09-26       2  ...      0      0      0      0
# 499         508   20266147 1966-10-07       2  ...      0      0      0      0
#
# [500 rows x 98 columns]

# %%
df_dv1.rename(columns = {'Person ID':'PERSON ID'}, inplace = True) 
df_dv2.rename(columns = {'Person ID':'PERSON ID'}, inplace = True)
df_dv3.rename(columns = {'Person ID':'PERSON ID'}, inplace = True) 
df_dv4.rename(columns = {'Person ID':'PERSON ID'}, inplace = True)
df_dv5.rename(columns = {'Person ID':'PERSON ID'}, inplace = True) 
df_dv6.rename(columns = {'Person ID':'PERSON ID'}, inplace = True)
df_dv7.rename(columns = {'Person ID':'PERSON ID'}, inplace = True) 
df_dv8.rename(columns = {'Person ID':'PERSON ID'}, inplace = True)
df_dv9.rename(columns = {'Person ID':'PERSON ID'}, inplace = True) 
df_dv10.rename(columns = {'Person ID':'PERSON ID'}, inplace = True)

# %%
df_ESRD_P1_2020 = pd.merge(df_d1,df_dv1,on ="PERSON ID", how="inner")
df_ESRD_P1_2020
# Out:
#       Unnamed: 0_x  PERSON ID DIAGNOSIS CODE    HCC  ...  NEM66 NEM67  NEM68  NEM69
# 0                0   59011425           N179  135.0  ...      0     0      0      0
# 1               63   59011425          E1142   18.0  ...      0     0      0      0
# 2               64   59011425          E1142   75.0  ...      0     0      0      0
# 3              386   59011425         E11610   18.0  ...      0     0      0      0
# 4              452   59011425           E118   18.0  ...      0     0      0      0
# ...            ...        ...            ...    ...  ...    ...   ...    ...    ...
# 2172          2072  128707425           I739  108.0  ...      0     0      1      0
# 2173          2074   19804968           I739  108.0  ...      0     0      0      0
# 2174          2126  132178472          E6601   22.0  ...      0     0      0      0
# 2175          2134  152542839          E6601   22.0  ...      0     0      0      0
# ...

# %%
df_ESRD_P1_2021 = pd.merge(df_d2,df_dv2,on ="PERSON ID", how="inner")
df_ESRD_P2_2020 = pd.merge(df_d3,df_dv3,on ="PERSON ID", how="inner")
df_ESRD_P2_2021 = pd.merge(df_d4,df_dv4,on ="PERSON ID", how="inner")
df_RX_2020 = pd.merge(df_d5,df_dv5,on ="PERSON ID", how="inner")
df_RX_2021 = pd.merge(df_d6,df_dv6,on ="PERSON ID", how="inner")
df_V22_2020 = pd.merge(df_d7,df_dv7,on ="PERSON ID", how="inner")
df_V22_2021 = pd.merge(df_d8,df_dv8,on ="PERSON ID", how="inner")
df_V24_2020 = pd.merge(df_d9,df_dv9,on ="PERSON ID", how="inner")
df_V24_2021 = pd.merge(df_d10,df_dv10,on ="PERSON ID", how="inner")

# %%
df_ESRD_P1_2021
# Out:
#       Unnamed: 0_x  PERSON ID DIAGNOSIS CODE    HCC  ...  NEM66 NEM67  NEM68  NEM69
# 0                1   71251632           N179  135.0  ...      0     0      0      0
# 1              150   71251632           I509   85.0  ...      0     0      0      0
# 2              486   71251632           I482   96.0  ...      0     0      0      0
# 3              549   71251632        T83410A  176.0  ...      0     0      0      0
# 4              602   71251632           D696   48.0  ...      0     0      0      0
# ...            ...        ...            ...    ...  ...    ...   ...    ...    ...
# 2148          2072  128707425           I739  108.0  ...      0     0      0      1
# 2149          2074   19804968           I739  108.0  ...      0     0      0      0
# 2150          2126  132178472          E6601   22.0  ...      0     0      0      0
# 2151          2134  152542839          E6601   22.0  ...      0     0      0      0
# ...

# %%
cc_over = '/content/drive/MyDrive/Index/CC Override Rules-mod.xlsx'
df_CC = pd.read_excel(cc_over)
df_CC
# Out:
#     MODEL YEAR  ...                                    DIAGNOSIS CODES
# 0         2020  ...                                      ('D66','D67')
# 1         2020  ...  ('J410','J411','J418','J42','J430','J431','J43...
# 2         2020  ...                                          ('F3481')
# 3         2020  ...                                          ('F3481')
# 4         2020  ...                                      ('D66','D67')
# 5         2020  ...  ('J410','J411','J418','J42','J430','J431','J43...
# 6         2020  ...                                          ('F3481')
# 7         2020  ...                                      ('D66','D67')
# 8         2020  ...  ('J410','J411','J418','J42','J430','J431','J43...
# 9         2020  ...                                          ('F3481')
# 10        2020  ...                                      ('D66','D67')
# 11        2020  ...  ('J410','J411','J418','J42','J430','J431','J43...
# ...

# %%
df_CC['CONDITION'][0]
# Out:
# "(data['Gender'] == 2) & ((data['DIAGNOSIS CODE'] == 'D66')|(data['DIAGNOSIS CODE'] == 'D67')) "

# %%
frames = [df_ESRD_P1_2020,df_ESRD_P1_2021,df_ESRD_P2_2020,df_ESRD_P2_2021,df_RX_2020,df_RX_2021,df_V22_2020,df_V22_2021,df_V24_2020,df_V24_2021]

result = pd.concat(frames)

# %%
result.to_excel("data.xlsx")

# %%
#test Code
df_ESRD_P1_2020.loc[(df_ESRD_P1_2020['PERSON ID'] == 67928991)]
# Out:
#     Unnamed: 0_x  PERSON ID DIAGNOSIS CODE  HCC  ...  NEM66 NEM67  NEM68  NEM69
# 7              7   67928991           I739  108  ...      0     0      0      0
# 8              8   67928991           J449  111  ...      0     0      0      0
# 9              9   67928991         I70213  108  ...      0     0      0      0
# 10            10   67928991            D66   46  ...      0     0      0      0
# 11            11   67928991           I700  108  ...      0     0      0      0
#
# [5 rows x 190 columns]

# %%
df_ESRD_P1_2021.loc[(df_ESRD_P1_2020['PERSON ID'] == 67928991)]
# Out:
#     Unnamed: 0_x  PERSON ID DIAGNOSIS CODE  HCC  ...  NEM66 NEM67  NEM68  NEM69
# 7              7   67928991           I739  108  ...      0     0      0      0
# 8              8   67928991           J449  111  ...      0     0      0      0
# 9              9   67928991         I70213  108  ...      0     0      0      0
# 10            10   67928991            D66   46  ...      0     0      0      0
# 11            11   67928991           I700  108  ...      0     0      0      0
#
# [5 rows x 190 columns]

# %%
df_ESRD_P2_2020.loc[(df_ESRD_P1_2020['PERSON ID'] == 67928991)]
# Out:
#     Unnamed: 0_x  PERSON ID DIAGNOSIS CODE  HCC  ...  NEM66 NEM67  NEM68  NEM69
# 7              7   67928991           I739  108  ...      0     0      0      0
# 8              8   67928991           J449  111  ...      0     0      0      0
# 9              9   67928991         I70213  108  ...      0     0      0      0
# 10            10   67928991            D66   46  ...      0     0      0      0
# 11            11   67928991           I700  108  ...      0     0      0      0
#
# [5 rows x 198 columns]

# %%
df_ESRD_P2_2020.loc[(df_ESRD_P1_2020['PERSON ID'] == 11474346)]
# Out:
#     Unnamed: 0_x  PERSON ID DIAGNOSIS CODE  HCC  ...  NEM66 NEM67  NEM68  NEM69
# 69            69   11474346           J479  112  ...      0     0      0      0
# 70            70   11474346           J441  111  ...      0     0      0      0
# 71            71   11474346           J449  111  ...      0     0      0      0
# 72            72   11474346          I7409  107  ...      0     0      0      0
# 73            73   11474346           E119   19  ...      0     0      0      0
# 74            74   11474346         I70213  108  ...      0     0      0      0
# 75            75   11474346           J439  111  ...      0     0      0      0
# 76            76   11474346           I739  108  ...      0     0      0      0
# 77            77   11474346           I700  108  ...      0     0      0      0
# 78            78   11474346         I70203  108  ...      0     0      0      0
#
# [10 rows x 198 columns]

# %%
df_ESRD_P2_2020.loc[(df_ESRD_P1_2020['PERSON ID'] == 25100092)]
# Out:
#       Unnamed: 0_x  PERSON ID DIAGNOSIS CODE HCC  ...  NEM66 NEM67  NEM68  NEM69
# 1313          1313   25100092           E119  19  ...      0     0      0      0
# 1314          1314   25100092          E1165  18  ...      0     0      0      0
# 1315          1315   25100092          I4891  96  ...      0     0      0      0
# 1316          1316   25100092           F349  58  ...      0     0      0      0
# 1317          1317   25100092           I482  96  ...      0     0      0      0
# 1318          1318   25100092         D68318  48  ...      0     0      0      0
#
# [6 rows x 198 columns]

# %%
#df_ESRD_P2_2021.loc[(df_ESRD_P1_2020['PERSON ID'] == 11474436)]

# %%
#ESRD-p1-2020
df_ESRD_P1_2020.loc[(df_ESRD_P1_2020['Gender'] == 2) & ((df_ESRD_P1_2020['DIAGNOSIS CODE'] == 'D66')|(df_ESRD_P1_2020['DIAGNOSIS CODE'] == 'D67')),['HCC']] = 48 
df_ESRD_P1_2020.loc[(df_ESRD_P1_2020['Age']< 18) & ((df_ESRD_P1_2020['DIAGNOSIS CODE'] == 'J410')|(df_ESRD_P1_2020['DIAGNOSIS CODE'] == 'J411')|(df_ESRD_P1_2020['DIAGNOSIS CODE'] == 'J418')|(df_ESRD_P1_2020['DIAGNOSIS CODE'] == 'J42')|(df_ESRD_P1_2020['DIAGNOSIS CODE'] == 'J430')|(df_ESRD_P1_2020['DIAGNOSIS CODE'] == 'J431')|(df_ESRD_P1_2020['DIAGNOSIS CODE'] == 'J432')|(df_ESRD_P1_2020['DIAGNOSIS CODE'] == 'J438')|(df_ESRD_P1_2020['DIAGNOSIS CODE'] == 'J439')|(df_ESRD_P1_2020['DIAGNOSIS CODE'] == 'J440')|(df_ESRD_P1_2020['DIAGNOSIS CODE'] == 'J441')|(df_ESRD_P1_2020['DIAGNOSIS CODE'] == 'J449')|(df_ESRD_P1_2020['DIAGNOSIS CODE'] == 'J982')|(df_ESRD_P1_2020['DIAGNOSIS CODE'] == 'J983')),['HCC']]=112
df_ESRD_P1_2020.loc[((df_ESRD_P1_2020['Age'] < 6)|(df_ESRD_P1_2020['Age'] > 18)) & (df_ESRD_P1_2020['DIAGNOSIS CODE'] == 'F3481'),['HCC']]= -1 

#ESRD-p1-2021
df_ESRD_P1_2021.loc[(df_ESRD_P1_2021['Gender'] == 2) & ((df_ESRD_P1_2021['DIAGNOSIS CODE'] == 'D66')|(df_ESRD_P1_2021['DIAGNOSIS CODE'] == 'D67')),['HCC']] = 48 
df_ESRD_P1_2021.loc[(df_ESRD_P1_2021['Age']< 18) & ((df_ESRD_P1_2021['DIAGNOSIS CODE'] == 'J410')|(df_ESRD_P1_2021['DIAGNOSIS CODE'] == 'J411')|(df_ESRD_P1_2021['DIAGNOSIS CODE'] == 'J418')|(df_ESRD_P1_2021['DIAGNOSIS CODE'] == 'J42')|(df_ESRD_P1_2021['DIAGNOSIS CODE'] == 'J430')|(df_ESRD_P1_2021['DIAGNOSIS CODE'] == 'J431')|(df_ESRD_P1_2021['DIAGNOSIS CODE'] == 'J432')|(df_ESRD_P1_2021['DIAGNOSIS CODE'] == 'J438')|(df_ESRD_P1_2021['DIAGNOSIS CODE'] == 'J439')|(df_ESRD_P1_2021['DIAGNOSIS CODE'] == 'J440')|(df_ESRD_P1_2021['DIAGNOSIS CODE'] == 'J441')|(df_ESRD_P1_2021['DIAGNOSIS CODE'] == 'J449')|(df_ESRD_P1_2021['DIAGNOSIS CODE'] == 'J982')|(df_ESRD_P1_2021['DIAGNOSIS CODE'] == 'J983')),['HCC']]=112
df_ESRD_P1_2021.loc[((df_ESRD_P1_2021['Age'] < 6)|(df_ESRD_P1_2021['Age'] > 18)) & (df_ESRD_P1_2021['DIAGNOSIS CODE'] == 'F3481'),['HCC']]= -1 

#ESRD-p2-2020
df_ESRD_P2_2020.loc[(df_ESRD_P2_2020['Gender'] == 2) & ((df_ESRD_P2_2020['DIAGNOSIS CODE'] == 'D66')|(df_ESRD_P2_2020['DIAGNOSIS CODE'] == 'D67')),['HCC']] = 48 
df_ESRD_P2_2020.loc[(df_ESRD_P2_2020['Age']< 18) & ((df_ESRD_P2_2020['DIAGNOSIS CODE'] == 'J410')|(df_ESRD_P2_2020['DIAGNOSIS CODE'] == 'J411')|(df_ESRD_P2_2020['DIAGNOSIS CODE'] == 'J418')|(df_ESRD_P2_2020['DIAGNOSIS CODE'] == 'J42')|(df_ESRD_P2_2020['DIAGNOSIS CODE'] == 'J430')|(df_ESRD_P2_2020['DIAGNOSIS CODE'] == 'J431')|(df_ESRD_P2_2020['DIAGNOSIS CODE'] == 'J432')|(df_ESRD_P2_2020['DIAGNOSIS CODE'] == 'J438')|(df_ESRD_P2_2020['DIAGNOSIS CODE'] == 'J439')|(df_ESRD_P2_2020['DIAGNOSIS CODE'] == 'J440')|(df_ESRD_P2_2020['DIAGNOSIS CODE'] == 'J441')|(df_ESRD_P2_2020['DIAGNOSIS CODE'] == 'J449')|(df_ESRD_P2_2020['DIAGNOSIS CODE'] == 'J982')|(df_ESRD_P2_2020['DIAGNOSIS CODE'] == 'J983')),['HCC']]=112
df_ESRD_P2_2020.loc[((df_ESRD_P2_2020['Age'] < 6)|(df_ESRD_P2_2020['Age'] > 18)) & (df_ESRD_P2_2020['DIAGNOSIS CODE'] == 'F3481'),['HCC']]= -1 

#ESRD-p2-2021
df_ESRD_P2_2021.loc[(df_ESRD_P2_2021['Gender'] == 2) & ((df_ESRD_P2_2021['DIAGNOSIS CODE'] == 'D66')|(df_ESRD_P2_2021['DIAGNOSIS CODE'] == 'D67')),['HCC']] = 48 
df_ESRD_P2_2021.loc[(df_ESRD_P2_2021['Age']< 18) & ((df_ESRD_P2_2021['DIAGNOSIS CODE'] == 'J410')|(df_ESRD_P2_2021['DIAGNOSIS CODE'] == 'J411')|(df_ESRD_P2_2021['DIAGNOSIS CODE'] == 'J418')|(df_ESRD_P2_2021['DIAGNOSIS CODE'] == 'J42')|(df_ESRD_P2_2021['DIAGNOSIS CODE'] == 'J430')|(df_ESRD_P2_2021['DIAGNOSIS CODE'] == 'J431')|(df_ESRD_P2_2021['DIAGNOSIS CODE'] == 'J432')|(df_ESRD_P2_2021['DIAGNOSIS CODE'] == 'J438')|(df_ESRD_P2_2021['DIAGNOSIS CODE'] == 'J439')|(df_ESRD_P2_2021['DIAGNOSIS CODE'] == 'J440')|(df_ESRD_P2_2021['DIAGNOSIS CODE'] == 'J441')|(df_ESRD_P2_2021['DIAGNOSIS CODE'] == 'J449')|(df_ESRD_P2_2021['DIAGNOSIS CODE'] == 'J982')|(df_ESRD_P2_2021['DIAGNOSIS CODE'] == 'J983')),['HCC']]=112
df_ESRD_P2_2021.loc[((df_ESRD_P2_2021['Age'] < 6)|(df_ESRD_P2_2021['Age'] > 18)) & (df_ESRD_P2_2021['DIAGNOSIS CODE'] == 'F3481'),['HCC']]= -1 

#RX2021
df_RX_2020.loc[((df_RX_2020['Age'] < 6)|(df_RX_2020['Age'] > 18)) & (df_RX_2020['DIAGNOSIS CODE'] == 'F3481'),['HCC']]= 133

#RX2021
df_RX_2021.loc[((df_RX_2021['Age'] < 6)|(df_RX_2021['Age'] > 18)) & (df_RX_2021['DIAGNOSIS CODE'] == 'F3481'),['HCC']]= 133

#V22_2020
df_V22_2020.loc[(df_V22_2020['Gender'] == 2) & ((df_V22_2020['DIAGNOSIS CODE'] == 'D66')|(df_V22_2020['DIAGNOSIS CODE'] == 'D67')),['HCC']] = 48 
df_V22_2020.loc[(df_V22_2020['Age']< 18) & ((df_V22_2020['DIAGNOSIS CODE'] == 'J410')|(df_V22_2020['DIAGNOSIS CODE'] == 'J411')|(df_V22_2020['DIAGNOSIS CODE'] == 'J418')|(df_V22_2020['DIAGNOSIS CODE'] == 'J42')|(df_V22_2020['DIAGNOSIS CODE'] == 'J430')|(df_V22_2020['DIAGNOSIS CODE'] == 'J431')|(df_V22_2020['DIAGNOSIS CODE'] == 'J432')|(df_V22_2020['DIAGNOSIS CODE'] == 'J438')|(df_V22_2020['DIAGNOSIS CODE'] == 'J439')|(df_V22_2020['DIAGNOSIS CODE'] == 'J440')|(df_V22_2020['DIAGNOSIS CODE'] == 'J441')|(df_V22_2020['DIAGNOSIS CODE'] == 'J449')|(df_V22_2020['DIAGNOSIS CODE'] == 'J982')|(df_V22_2020['DIAGNOSIS CODE'] == 'J983')),['HCC']]=112
df_V22_2020.loc[((df_V22_2020['Age'] < 6)|(df_V22_2020['Age'] > 18)) & (df_V22_2020['DIAGNOSIS CODE'] == 'F3481'),['HCC']]= -1 

#V22_2021
df_V22_2021.loc[(df_V22_2021['Gender'] == 2) & ((df_V22_2021['DIAGNOSIS CODE'] == 'D66')|(df_V22_2021['DIAGNOSIS CODE'] == 'D67')),['HCC']] = 48 
df_V22_2021.loc[(df_V22_2021['Age']< 18) & ((df_V22_2021['DIAGNOSIS CODE'] == 'J410')|(df_V22_2021['DIAGNOSIS CODE'] == 'J411')|(df_V22_2021['DIAGNOSIS CODE'] == 'J418')|(df_V22_2021['DIAGNOSIS CODE'] == 'J42')|(df_V22_2021['DIAGNOSIS CODE'] == 'J430')|(df_V22_2021['DIAGNOSIS CODE'] == 'J431')|(df_V22_2021['DIAGNOSIS CODE'] == 'J432')|(df_V22_2021['DIAGNOSIS CODE'] == 'J438')|(df_V22_2021['DIAGNOSIS CODE'] == 'J439')|(df_V22_2021['DIAGNOSIS CODE'] == 'J440')|(df_V22_2021['DIAGNOSIS CODE'] == 'J441')|(df_V22_2021['DIAGNOSIS CODE'] == 'J449')|(df_V22_2021['DIAGNOSIS CODE'] == 'J982')|(df_V22_2021['DIAGNOSIS CODE'] == 'J983')),['HCC']]=112
df_V22_2021.loc[((df_V22_2021['Age'] < 6)|(df_V22_2021['Age'] > 18)) & (df_V22_2021['DIAGNOSIS CODE'] == 'F3481'),['HCC']]= -1 

#ESRD-p2-2021
df_V24_2020.loc[(df_V24_2020['Gender'] == 2) & ((df_V24_2020['DIAGNOSIS CODE'] == 'D66')|(df_V24_2020['DIAGNOSIS CODE'] == 'D67')),['HCC']] = 48 
df_ESRD_P1_2021.loc[(df_V24_2020['Age']< 18) & ((df_V24_2020['DIAGNOSIS CODE'] == 'J410')|(df_V24_2020['DIAGNOSIS CODE'] == 'J411')|(df_V24_2020['DIAGNOSIS CODE'] == 'J418')|(df_V24_2020['DIAGNOSIS CODE'] == 'J42')|(df_V24_2020['DIAGNOSIS CODE'] == 'J430')|(df_V24_2020['DIAGNOSIS CODE'] == 'J431')|(df_V24_2020['DIAGNOSIS CODE'] == 'J432')|(df_V24_2020['DIAGNOSIS CODE'] == 'J438')|(df_V24_2020['DIAGNOSIS CODE'] == 'J439')|(df_V24_2020['DIAGNOSIS CODE'] == 'J440')|(df_V24_2020['DIAGNOSIS CODE'] == 'J441')|(df_V24_2020['DIAGNOSIS CODE'] == 'J449')|(df_V24_2020['DIAGNOSIS CODE'] == 'J982')|(df_V24_2020['DIAGNOSIS CODE'] == 'J983')),['HCC']]=112
df_V24_2020.loc[((df_V24_2020['Age'] < 6)|(df_V24_2020['Age'] > 18)) & (df_V24_2020['DIAGNOSIS CODE'] == 'F3481'),['HCC']]= -1 

#ESRD-p2-2021
df_V24_2021.loc[(df_V24_2021['Gender'] == 2) & ((df_V24_2021['DIAGNOSIS CODE'] == 'D66')|(df_V24_2021['DIAGNOSIS CODE'] == 'D67')),['HCC']] = 48 
df_V24_2021.loc[(df_V24_2021['Age']< 18) & ((df_V24_2021['DIAGNOSIS CODE'] == 'J410')|(df_V24_2021['DIAGNOSIS CODE'] == 'J411')|(df_V24_2021['DIAGNOSIS CODE'] == 'J418')|(df_V24_2021['DIAGNOSIS CODE'] == 'J42')|(df_V24_2021['DIAGNOSIS CODE'] == 'J430')|(df_V24_2021['DIAGNOSIS CODE'] == 'J431')|(df_V24_2021['DIAGNOSIS CODE'] == 'J432')|(df_V24_2021['DIAGNOSIS CODE'] == 'J438')|(df_V24_2021['DIAGNOSIS CODE'] == 'J439')|(df_V24_2021['DIAGNOSIS CODE'] == 'J440')|(df_V24_2021['DIAGNOSIS CODE'] == 'J441')|(df_V24_2021['DIAGNOSIS CODE'] == 'J449')|(df_V24_2021['DIAGNOSIS CODE'] == 'J982')|(df_V24_2021['DIAGNOSIS CODE'] == 'J983')),['HCC']]=112
df_V24_2021.loc[((df_V24_2021['Age'] < 6)|(df_V24_2021['Age'] > 18)) & (df_V24_2021['DIAGNOSIS CODE'] == 'F3481'),['HCC']]= -1

# %%
#test Code
df_ESRD_P2_2020.loc[(df_ESRD_P1_2020['PERSON ID'] == 25100092)]
# Out:
#       Unnamed: 0_x  PERSON ID DIAGNOSIS CODE HCC  ...  NEM66 NEM67  NEM68  NEM69
# 1313          1313   25100092           E119  19  ...      0     0      0      0
# 1314          1314   25100092          E1165  18  ...      0     0      0      0
# 1315          1315   25100092          I4891  96  ...      0     0      0      0
# 1316          1316   25100092           F349  58  ...      0     0      0      0
# 1317          1317   25100092           I482  96  ...      0     0      0      0
# 1318          1318   25100092         D68318  48  ...      0     0      0      0
#
# [6 rows x 198 columns]

# %%
df_ESRD_P1_2021.loc[(df_ESRD_P1_2020['PERSON ID'] == 67928991)]
# Out:
#     Unnamed: 0_x  PERSON ID DIAGNOSIS CODE  HCC  ...  NEM66 NEM67  NEM68  NEM69
# 7              7   67928991           I739  108  ...      0     0      0      0
# 8              8   67928991           J449  111  ...      0     0      0      0
# 9              9   67928991         I70213  108  ...      0     0      0      0
# 10            10   67928991            D66   48  ...      0     0      0      0
# 11            11   67928991           I700  108  ...      0     0      0      0
#
# [5 rows x 190 columns]

# %%
df_ESRD_P1_2020.to_excel("ESRD_P1_2020_CCO.xlsx")
df_ESRD_P1_2021.to_excel("ESRD_P1_2021_CCO.xlsx")
df_ESRD_P2_2020.to_excel("ESRD_P2_2020_CCO.xlsx")
df_ESRD_P2_2021.to_excel("ESRD_P2_2021_CCO.xlsx")
df_RX_2020.to_excel("RX_2020_CCO.xlsx")
df_RX_2021.to_excel("RX_2021_CCO.xlsx")
df_V22_2020.to_excel("V22_2020_CCO.xlsx")
df_V22_2021.to_excel("V22_2021_CCO.xlsx")
df_V24_2020.to_excel("V24_2020_CCO.xlsx")
df_V24_2021.to_excel("V24_2021_CCO.xlsx")

# %%
df_ESRD_P1_2021
# Out:
#       Unnamed: 0_x  PERSON ID DIAGNOSIS CODE  ... NEM67  NEM68 NEM69
# 0                0   95307787          E1165  ...     0      0     0
# 1                1   95307787          E1122  ...     0      0     0
# 2                2   95307787           E230  ...     0      0     0
# 3                3   95307787           E119  ...     0      0     0
# 4                4   95307787          E1151  ...     0      0     0
# ...            ...        ...            ...  ...   ...    ...   ...
# 1966          1987  106185394          E6601  ...     0      0     0
# 1967          1988   31405988           M069  ...     0      0     0
# 1968          1989   40752647          Z6841  ...     0      0     0
# 1969          1990  150788750         F10929  ...     1      0     0
# 1970          1991   87823398          F3110  ...     0      0     0
#
# [1971 rows x 190 columns]

# %%
# df_ESRD_P1_2020
# df_ESRD_P1_2021 -- 
# df_ESRD_P2_2020
# df_ESRD_P2_2021
# df_RX_2020
# df_RX_2021
# df_V22_2020
# df_V22_2021
# df_V24_2020
# df_V24_2021

# %%
df_list_ESRD = [df_ESRD_P1_2020, df_ESRD_P1_2021, df_ESRD_P2_2020, df_ESRD_P2_2021]
df_list_Rx = [df_RX_2020, df_RX_2021]
df_list_Vx= [df_V22_2020,df_V22_2021,df_V24_2020,df_V24_2021]

# %%
df_list_ESRD
# Out:
# [      Unnamed: 0_x  PERSON ID DIAGNOSIS CODE  ... NEM67  NEM68 NEM69
#  0                0   95307787          E1165  ...     0      0     0
#  1                1   95307787          E1122  ...     0      0     0
#  2                2   95307787           E230  ...     0      0     0
#  3                3   95307787           E119  ...     0      0     0
#  4                4   95307787          E1151  ...     0      0     0
#  ...            ...        ...            ...  ...   ...    ...   ...
#  1987          1987  106185394          E6601  ...     0      0     0
#  1988          1988   31405988           M069  ...     0      0     0
#  1989          1989   40752647          Z6841  ...     0      0     0
#  1990          1990  150788750         F10929  ...     0      0     0
#  1991          1991   87823398          F3110  ...     0      0     0
#
#  [1992 rows x 190 columns],
#        Unnamed: 0_x  PERSON ID DIAGNOSIS CODE  ... NEM67  NEM68 NEM69
# ...

# %%
result = []
for dat in df_list_ESRD:
  dat = result.append(dat.groupby(['PERSON ID','MODEL YEAR','Version','DOB','Gender','Age','Model Year','Model Version'] ).agg(
     HCC1 = ('HCC1','max'),HCC2 = ('HCC2','max'),HCC6 = ('HCC6','max'),HCC8 = ('HCC8','max'),HCC9 = ('HCC9','max'),HCC10 = ('HCC10','max'),HCC11 = ('HCC11','max'),HCC12 = ('HCC12','max'),
     HCC17 = ('HCC17','max'),HCC18 = ('HCC18','max'),HCC19 = ('HCC19','max'),HCC21 = ('HCC21','max'),HCC22 = ('HCC22','max'),HCC23 = ('HCC23','max'),HCC27 = ('HCC27','max'),
     HCC28 = ('HCC28','max'),HCC29 = ('HCC29','max'),HCC33 = ('HCC33','max'),HCC34 = ('HCC34','max'),HCC35 = ('HCC35','max'),HCC39 = ('HCC39','max'),HCC40 = ('HCC40','max'),
     HCC46 = ('HCC46','max'),HCC47 = ('HCC47','max'),HCC48 = ('HCC48','max'),HCC51 = ('HCC51','max'),HCC52 = ('HCC52','max'),HCC54 = ('HCC54','max'),HCC55 = ('HCC55','max'),
     HCC57 = ('HCC57','max'),HCC58 = ('HCC58','max'),HCC70 = ('HCC70','max'),HCC71 = ('HCC71','max'),HCC72 = ('HCC72','max'),HCC73 = ('HCC73','max'),HCC74 = ('HCC74','max'),																	
     HCC75 = ('HCC75','max'),HCC76 = ('HCC76','max'),HCC77 = ('HCC77','max'),HCC78 = ('HCC78','max'),HCC79 = ('HCC79','max'),HCC80 = ('HCC80','max'),HCC82 = ('HCC82','max'),
     HCC83 = ('HCC83','max'),HCC84 = ('HCC84','max'),HCC85 = ('HCC85','max'),HCC86 = ('HCC86','max'),HCC87 = ('HCC87','max'),HCC88 = ('HCC88','max'),HCC96 = ('HCC96','max'),
     HCC99 = ('HCC99','max'), HCC100 = ('HCC100','max'),HCC103 = ('HCC103','max'),HCC104 = ('HCC104','max'),HCC106 = ('HCC106','max'),HCC107 = ('HCC107','max'),HCC108 = ('HCC108','max'),
     HCC110 = ('HCC110','max'),HCC111 = ('HCC111','max'),HCC112 = ('HCC112','max'),HCC114 = ('HCC114','max'),HCC115 = ('HCC115','max'),HCC122 = ('HCC122','max'),HCC124 = ('HCC124','max'),
     HCC134 = ('HCC134','max'),HCC135 = ('HCC135','max'),HCC136 = ('HCC136','max'),HCC137 = ('HCC137','max'),HCC138 = ('HCC138','max'),HCC139 = ('HCC139','max'),HCC140 = ('HCC140','max'),HCC141 = ('HCC141','max'),
     HCC157 = ('HCC157','max'),HCC158 = ('HCC158','max'),HCC159 = ('HCC159','max'),HCC160 = ('HCC160','max'),HCC161 = ('HCC161','max'),HCC162 = ('HCC162','max'),HCC166 = ('HCC166','max'),
     HCC167 = ('HCC167','max'),HCC169 = ('HCC169','max'),HCC170 = ('HCC170','max'),HCC173 = ('HCC173','max'),HCC176 = ('HCC176','max'),HCC186 = ('HCC186','max'),HCC188 = ('HCC188','max'),
     HCC189 = ('HCC189','max'),OREC = ('OREC','max'),LTIMCAID = ('LTIMCAID','max'),NMCAID_NORIGDIS = ('NMCAID_NORIGDIS','max'),NMCAID_NORIGDIS_G = ('NMCAID_NORIGDIS_G','max'),NMCAID_ORIGDIS = ('NMCAID_ORIGDIS','max'),NMCAID_ORIGDIS_G = ('NMCAID_ORIGDIS_G','max'),
     NEMCAID = ('NEMCAID','max'),ESRD = ('ESRD','max'),MCAID = ('MCAID','max'),GE65_DUR10PL = ('GE65_DUR10PL','max'),GE65_DUR4_9 = ('GE65_DUR4_9','max'),LT65_DUR10PL = ('LT65_DUR10PL','max'),LT65_DUR4_9 = ('LT65_DUR4_9','max'),																	
     NEF85_GT = ('NEF85_GT','max'),NEM85_GT = ('NEM85_GT','max'),ORIGDS = ('ORIGDS','max'),Originally_ESRD_Female = ('Originally_ESRD_Female','max'),Originally_ESRD_Male = ('Originally_ESRD_Male','max'),OriginallyDisabled_Female = ('OriginallyDisabled_Female','max'),OriginallyDisabled_Male = ('OriginallyDisabled_Male','max'),
     MCAID_Female_Aged = ('MCAID_Female_Aged','max'),MCAID_Male_Aged = ('MCAID_Male_Aged','max'),MCAID_Female_NonAged = ('MCAID_Female_NonAged','max'),MCAID_Male_NonAged = ('MCAID_Male_NonAged','max'),MCAID_NORIGDIS = ('MCAID_NORIGDIS','max'),MCAID_NORIGDIS_G = ('MCAID_NORIGDIS_G','max'),MCAID_O = ('MCAID_O','max'),
     MCAID_ORIGDIS = ('MCAID_ORIGDIS','max'), MCAID_ORIGDIS_G = ('MCAID_ORIGDIS_G','max'),NE_ORIGDS = ('NE_ORIGDS','max'),NE_ORIGDS_G = ('NE_ORIGDS_G','max'),KIDNEY_ONLY_1M = ('KIDNEY_ONLY_1M','max'),KIDNEY_ONLY_2M = ('KIDNEY_ONLY_2M','max'),KIDNEY_ONLY_3M = ('KIDNEY_ONLY_3M','max'),
     DISABL = ('DISABL','max'),F0_34 = ('F0_34','max'),NEF0_34 = ('NEF0_34','max'),F35_44 = ('F35_44','max'),NEF35_44 = ('NEF35_44','max'),F45_54 = ('F45_54','max'),NEF45_54 = ('NEF45_54','max'),
     F55_59 = ('F55_59','max'),NEF55_59 = ('NEF55_59','max'),F60_64 = ('F60_64','max'),F65_69 = ('F65_69','max'),F70_74 = ('F70_74','max'),NEF70_74 = ('NEF70_74','max'),F75_79 = ('F75_79','max'),NEF75_79 = ('NEF75_79','max'),
     F80_84 = ('F80_84','max'),NEF80_84 = ('NEF80_84','max'),F85_89 = ('F85_89','max'),NEF85_89 = ('NEF85_89','max'),F90_94 = ('F90_94','max'),NEF90_94 = ('NEF90_94','max'),F95_GT = ('F95_GT','max'),
     NEF95_GT = ('NEF95_GT','max'),M0_34 = ('M0_34','max'),NEM0_34 = ('NEM0_34','max'),M35_44 = ('M35_44','max'),NEM35_44 = ('NEM35_44','max'),M45_54 = ('M45_54','max'),NEM45_54 = ('NEM45_54','max'),
     M55_59 = ('M55_59','max'),NEM55_59 = ('NEM55_59','max'),M60_64 = ('M60_64','max'),M65_69 = ('M65_69','max'),M70_74 = ('M70_74','max'),NEM70_74 = ('NEM70_74','max'),M75_79 = ('M75_79','max'),
     NEM75_79 = ('NEM75_79','max'),M80_84 = ('M80_84','max'),NEM80_84 = ('NEM80_84','max'),M85_89 = ('M85_89','max'),NEM85_89 = ('NEM85_89','max'),M90_94 = ('M90_94','max'),NEM90_94 = ('NEM90_94','max'),M95_GT = ('M95_GT','max'),NEM95_GT = ('NEM95_GT','max'),
     NEF60_64 = ('NEF60_64','max'),NEF65 = ('NEF65','max'),NEF66 = ('NEF66','max'),NEF67 = ('NEF67','max'),NEF68 = ('NEF68','max'),NEF69 = ('NEF69','max'),NEM60_64 = ('NEM60_64','max'),
     NEM65 = ('NEM65','max'),NEM66 = ('NEM66','max'),NEM67 = ('NEM67','max'),NEM68 = ('NEM68','max'),NEM69 = ('NEM69','max')
     ).reset_index())
     

#print(result)

# %%
[df_ESRD_P1_2020, df_ESRD_P1_2021, df_ESRD_P2_2020, df_ESRD_P2_2021] = result

# %%
result2 = []
for dat in df_list_Rx:
  dat = result2.append(dat.groupby(['PERSON ID','MODEL YEAR','Version','DOB','Gender','Age','Model Year','Model Version'] ).agg(
     HCC1 = ('HCC1','max'),HCC5 = ('HCC5','max'),HCC15 = ('HCC15','max'),HCC16 = ('HCC16','max'),HCC17 = ('HCC17','max'),HCC18 = ('HCC18','max'),HCC19 = ('HCC19','max'),
     HCC30 = ('HCC30','max'),HCC31 = ('HCC31','max'),HCC40 = ('HCC40','max'),HCC41 = ('HCC41','max'),HCC42 = ('HCC42','max'),HCC45 = ('HCC45','max'),HCC54 = ('HCC54','max'),HCC55 = ('HCC55','max'),
     HCC65 = ('HCC65','max'),HCC66 = ('HCC66','max'),HCC67 = ('HCC67','max'),HCC68 = ('HCC68','max'),HCC80 = ('HCC80','max'),HCC82 = ('HCC82','max'),
     HCC83 = ('HCC83','max'),HCC84 = ('HCC84','max'),HCC87 = ('HCC87','max'),HCC95 = ('HCC95','max'),HCC96 = ('HCC96','max'), HCC97 = ('HCC97','max'),HCC98 = ('HCC98','max'),
     HCC111 = ('HCC111','max'),HCC112 = ('HCC112','max'),HCC130 = ('HCC130','max'),HCC131 = ('HCC131','max'),HCC132 = ('HCC132','max'),HCC133 = ('HCC133','max'),HCC134 = ('HCC134','max'),HCC135 = ('HCC135','max'),
     HCC145 = ('HCC145','max'),HCC146 = ('HCC146','max'),HCC147 = ('HCC147','max'),HCC148 = ('HCC148','max'),HCC156 = ('HCC156','max'),
     HCC157 = ('HCC157','max'),HCC159 = ('HCC159','max'),HCC160 = ('HCC160','max'),HCC161 = ('HCC161','max'),HCC163 = ('HCC163','max'),HCC164 = ('HCC164','max'),HCC165 = ('HCC165','max'),HCC166 = ('HCC166','max'),
     HCC168 = ('HCC168','max'),HCC185 = ('HCC185','max'),HCC186 = ('HCC186','max'),HCC187 = ('HCC187','max'),HCC188 = ('HCC188','max'),
     HCC193 = ('HCC193','max'),HCC206 = ('HCC206','max'),HCC207 = ('HCC207','max'),HCC215 = ('HCC215','max'),HCC216 = ('HCC216','max'),HCC225 = ('HCC225','max'),HCC226 = ('HCC226','max'),HCC227 = ('HCC227','max'),
     HCC241 = ('HCC241','max'),HCC243 = ('HCC243','max'),HCC260 = ('HCC260','max'),HCC261 = ('HCC261','max'),HCC262 = ('HCC262','max'),
     HCC263 = ('HCC263','max'),HCC311 = ('HCC311','max'),HCC314 = ('HCC314','max'),HCC316 = ('HCC316','max'),HCC355 = ('HCC355','max'),HCC395 = ('HCC395','max'),HCC396 = ('HCC396','max'),HCC397 = ('HCC397','max'),
     OREC = ('OREC','max'),LTIMCAID = ('LTIMCAID','max'),NEMCAID = ('NEMCAID','max'),ESRD = ('ESRD','max'),MCAID = ('MCAID','max'),ESRD_NORIGDIS = ('ESRD_NORIGDIS','max'),ESRD_ORIGDIS = ('ESRD_ORIGDIS','max'),F65OD = ('F65OD','max'),M65OD = ('M65OD','max'),	NESRD_NORIGDIS = ('NESRD_NORIGDIS','max'),															
     ORIGDS = ('ORIGDS','max'),NonAged = ('NonAged','max'),F0_34 = ('F0_34','max'),NEF0_34 = ('NEF0_34','max'),F35_44 = ('F35_44','max'),NEF35_44 = ('NEF35_44','max'),F45_54 = ('F45_54','max'),NEF45_54 = ('NEF45_54','max'),
     F55_59 = ('F55_59','max'),NEF55_59 = ('NEF55_59','max'),F60_64 = ('F60_64','max'),F65_69 = ('F65_69','max'),F70_74 = ('F70_74','max'),NEF70_74 = ('NEF70_74','max'),F75_79 = ('F75_79','max'),NEF75_79 = ('NEF75_79','max'),
     F80_84 = ('F80_84','max'),NEF80_84 = ('NEF80_84','max'),F85_89 = ('F85_89','max'),NEF85_89 = ('NEF85_89','max'),F90_94 = ('F90_94','max'),NEF90_94 = ('NEF90_94','max'),F95_GT = ('F95_GT','max'),
     NEF95_GT = ('NEF95_GT','max'),M0_34 = ('M0_34','max'),NEM0_34 = ('NEM0_34','max'),M35_44 = ('M35_44','max'),NEM35_44 = ('NEM35_44','max'),M45_54 = ('M45_54','max'),NEM45_54 = ('NEM45_54','max'),
     M55_59 = ('M55_59','max'),NEM55_59 = ('NEM55_59','max'),M60_64 = ('M60_64','max'),M65_69 = ('M65_69','max'),M70_74 = ('M70_74','max'),NEM70_74 = ('NEM70_74','max'),M75_79 = ('M75_79','max'),
     NEM75_79 = ('NEM75_79','max'),M80_84 = ('M80_84','max'),NEM80_84 = ('NEM80_84','max'),M85_89 = ('M85_89','max'),NEM85_89 = ('NEM85_89','max'),M90_94 = ('M90_94','max'),NEM90_94 = ('NEM90_94','max'),M95_GT = ('M95_GT','max'),NEM95_GT = ('NEM95_GT','max'),
     NEF60_64 = ('NEF60_64','max'),NEF65 = ('NEF65','max'),NEF66 = ('NEF66','max'),NEF67 = ('NEF67','max'),NEF68 = ('NEF68','max'),NEF69 = ('NEF69','max'),NEM60_64 = ('NEM60_64','max'),
     NEM65 = ('NEM65','max'),NEM66 = ('NEM66','max'),NEM67 = ('NEM67','max'),NEM68 = ('NEM68','max'),NEM69 = ('NEM69','max')
     

     ).reset_index())
     

#print(result)

# %%
[df_RX_2020, df_RX_2021] = result2

# %%
df_RX_2020
# Out:
#      PERSON ID  MODEL YEAR Version        DOB  ...  NEM66  NEM67  NEM68 NEM69
# 0      1049180        2020      RX 1937-07-31  ...      0      0      0     0
# 1      1393478        2020      RX 1938-03-12  ...      0      0      0     0
# 2      2660169        2020      RX 1943-05-20  ...      0      0      0     0
# 3      2693705        2020      RX 1977-07-26  ...      0      0      0     0
# 4      2794680        2020      RX 1946-01-20  ...      0      0      0     0
# ..         ...         ...     ...        ...  ...    ...    ...    ...   ...
# 367  157935578        2020      RX 1950-12-04  ...      0      0      0     0
# 368  158141657        2020      RX 1951-06-24  ...      0      0      0     0
# 369  158547028        2020      RX 1952-05-03  ...      0      1      0     0
# 370  159127629        2020      RX 1943-07-29  ...      0      0      0     0
# 371  159798717        2020      RX 1953-07-02  ...      0      0      0     0
#
# [372 rows x 151 columns]

# %%
result3 = []
for dat in df_list_Vx:
  dat = result3.append(dat.groupby(['PERSON ID','MODEL YEAR','Version','DOB','Gender','Age','Model Year','Model Version'] ).agg(
     HCC1 = ('HCC1','max'),HCC2 = ('HCC2','max'),HCC6 = ('HCC6','max'),HCC8 = ('HCC8','max'),HCC9 = ('HCC9','max'),HCC10 = ('HCC10','max'),HCC11 = ('HCC11','max'),HCC12 = ('HCC12','max'),
     HCC17 = ('HCC17','max'),HCC18 = ('HCC18','max'),HCC19 = ('HCC19','max'),HCC21 = ('HCC21','max'),HCC22 = ('HCC22','max'),HCC23 = ('HCC23','max'),HCC27 = ('HCC27','max'),
     HCC28 = ('HCC28','max'),HCC29 = ('HCC29','max'),HCC33 = ('HCC33','max'),HCC34 = ('HCC34','max'),HCC35 = ('HCC35','max'),HCC39 = ('HCC39','max'),HCC40 = ('HCC40','max'),
     HCC46 = ('HCC46','max'),HCC47 = ('HCC47','max'),HCC48 = ('HCC48','max'),HCC54 = ('HCC54','max'),HCC55 = ('HCC55','max'),
     HCC57 = ('HCC57','max'),HCC58 = ('HCC58','max'),HCC70 = ('HCC70','max'),HCC71 = ('HCC71','max'),HCC72 = ('HCC72','max'),HCC73 = ('HCC73','max'),HCC74 = ('HCC74','max'),																	
     HCC75 = ('HCC75','max'),HCC76 = ('HCC76','max'),HCC77 = ('HCC77','max'),HCC78 = ('HCC78','max'),HCC79 = ('HCC79','max'),HCC80 = ('HCC80','max'),HCC82 = ('HCC82','max'),
     HCC83 = ('HCC83','max'),HCC84 = ('HCC84','max'),HCC85 = ('HCC85','max'),HCC86 = ('HCC86','max'),HCC87 = ('HCC87','max'),HCC88 = ('HCC88','max'),HCC96 = ('HCC96','max'),
     HCC99 = ('HCC99','max'), HCC100 = ('HCC100','max'),HCC103 = ('HCC103','max'),HCC104 = ('HCC104','max'),HCC106 = ('HCC106','max'),HCC107 = ('HCC107','max'),HCC108 = ('HCC108','max'),
     HCC110 = ('HCC110','max'),HCC111 = ('HCC111','max'),HCC112 = ('HCC112','max'),HCC114 = ('HCC114','max'),HCC115 = ('HCC115','max'),HCC122 = ('HCC122','max'),HCC124 = ('HCC124','max'),
     HCC134 = ('HCC134','max'),HCC135 = ('HCC135','max'),HCC136 = ('HCC136','max'),HCC137 = ('HCC137','max'),
     HCC157 = ('HCC157','max'),HCC158 = ('HCC158','max'),HCC161 = ('HCC161','max'),HCC162 = ('HCC162','max'),HCC166 = ('HCC166','max'),
     HCC167 = ('HCC167','max'),HCC169 = ('HCC169','max'),HCC170 = ('HCC170','max'),HCC173 = ('HCC173','max'),HCC176 = ('HCC176','max'),HCC186 = ('HCC186','max'),HCC188 = ('HCC188','max'),
     HCC189 = ('HCC189','max'),OREC = ('OREC','max'),LTIMCAID = ('LTIMCAID','max'),NEMCAID = ('NEMCAID','max'),ESRD = ('ESRD','max'),MCAID = ('MCAID','max'), DISABL = ('DISABL','max'),
     MCAID_NORIGDIS = ('MCAID_NORIGDIS','max'),MCAID_ORIGDIS = ('MCAID_ORIGDIS','max'),NE_ORIGDS = ('NE_ORIGDS','max'),NMCAID_NORIGDIS = ('NMCAID_NORIGDIS','max'),NMCAID_ORIGDIS = ('NMCAID_ORIGDIS','max'),
     F0_34 = ('F0_34','max'),NEF0_34 = ('NEF0_34','max'),F35_44 = ('F35_44','max'),NEF35_44 = ('NEF35_44','max'),F45_54 = ('F45_54','max'),NEF45_54 = ('NEF45_54','max'),
     F55_59 = ('F55_59','max'),NEF55_59 = ('NEF55_59','max'),F60_64 = ('F60_64','max'),F65_69 = ('F65_69','max'),F70_74 = ('F70_74','max'),NEF70_74 = ('NEF70_74','max'),F75_79 = ('F75_79','max'),NEF75_79 = ('NEF75_79','max'),
     F80_84 = ('F80_84','max'),NEF80_84 = ('NEF80_84','max'),F85_89 = ('F85_89','max'),NEF85_89 = ('NEF85_89','max'),F90_94 = ('F90_94','max'),NEF90_94 = ('NEF90_94','max'),F95_GT = ('F95_GT','max'),
     NEF95_GT = ('NEF95_GT','max'),M0_34 = ('M0_34','max'),NEM0_34 = ('NEM0_34','max'),M35_44 = ('M35_44','max'),NEM35_44 = ('NEM35_44','max'),M45_54 = ('M45_54','max'),NEM45_54 = ('NEM45_54','max'),
     M55_59 = ('M55_59','max'),NEM55_59 = ('NEM55_59','max'),M60_64 = ('M60_64','max'),M65_69 = ('M65_69','max'),M70_74 = ('M70_74','max'),NEM70_74 = ('NEM70_74','max'),M75_79 = ('M75_79','max'),
     NEM75_79 = ('NEM75_79','max'),M80_84 = ('M80_84','max'),NEM80_84 = ('NEM80_84','max'),M85_89 = ('M85_89','max'),NEM85_89 = ('NEM85_89','max'),M90_94 = ('M90_94','max'),NEM90_94 = ('NEM90_94','max'),M95_GT = ('M95_GT','max'),NEM95_GT = ('NEM95_GT','max'),
     NEF60_64 = ('NEF60_64','max'),NEF65 = ('NEF65','max'),NEF66 = ('NEF66','max'),NEF67 = ('NEF67','max'),NEF68 = ('NEF68','max'),NEF69 = ('NEF69','max'),NEM60_64 = ('NEM60_64','max'),
     NEM65 = ('NEM65','max'),NEM66 = ('NEM66','max'),NEM67 = ('NEM67','max'),NEM68 = ('NEM68','max'),NEM69 = ('NEM69','max')
     ).reset_index())
     

#print(result)

# %%
[df_V22_2020,df_V22_2021,df_V24_2020,df_V24_2021] = result3

# %%
df_V22_2021
# Out:
#      PERSON ID  MODEL YEAR Version        DOB  ...  NEM66  NEM67  NEM68 NEM69
# 0      1049180        2021     V22 1937-07-31  ...      0      0      0     0
# 1      1393478        2021     V22 1938-03-12  ...      0      0      0     0
# 2      2660169        2021     V22 1943-05-20  ...      0      0      0     0
# 3      2693705        2021     V22 1977-07-26  ...      0      0      0     0
# 4      2794680        2021     V22 1946-01-20  ...      0      0      0     0
# ..         ...         ...     ...        ...  ...    ...    ...    ...   ...
# 366  157935578        2021     V22 1950-12-04  ...      0      0      0     0
# 367  158141657        2021     V22 1951-06-24  ...      0      0      0     0
# 368  158547028        2021     V22 1952-05-03  ...      0      0      1     0
# 369  159127629        2021     V22 1943-07-29  ...      0      0      0     0
# 370  159798717        2021     V22 1953-07-02  ...      0      0      0     0
#
# [371 rows x 154 columns]

# %%
df_ESRD_P1_2020.to_excel("ESRD_P1_2020_CCO.xlsx")
df_ESRD_P1_2021.to_excel("ESRD_P1_2021_CCO.xlsx")
df_ESRD_P2_2020.to_excel("ESRD_P2_2020_CCO.xlsx")
df_ESRD_P2_2021.to_excel("ESRD_P2_2021_CCO.xlsx")
df_RX_2020.to_excel("RX_2020_CCO.xlsx")
df_RX_2021.to_excel("RX_2021_CCO.xlsx")
df_V22_2020.to_excel("V22_2020_CCO.xlsx")
df_V22_2021.to_excel("V22_2021_CCO.xlsx")
df_V24_2020.to_excel("V24_2020_CCO.xlsx")
df_V24_2021.to_excel("V24_2021_CCO.xlsx")
